# %% [markdown]
# # For what GBR parameters have we collected?

# %%
import numpy as np
import pandas as pd

collected = [
    {'n_estimators': 500, 'learning_rate': 0.05, 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 10, 'loss': 'huber', 'random_state': 42, 'totalRecords': 39150, 'totalIterations': 26.999999999999996, 'score': np.float64(0.11462593852333741)},
    {'n_estimators': 500, 'learning_rate': 0.01, 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 10, 'loss': 'huber', 'random_state': 420, 'totalRecords': 47850, 'totalIterations': 33.0, 'score': np.float64(0.12730785990421903)},
    {'n_estimators': 1000, 'learning_rate': 0.05, 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 10, 'loss': 'huber', 'random_state': 420, 'totalRecords': 27550, 'totalIterations': 19.0, 'score': np.float64(0.11342151693889647)},
    {'n_estimators': 500, 'learning_rate': 0.01, 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 10, 'loss': 'huber', 'random_state': 42, 'totalRecords': 73950, 'totalIterations': 50.99999999999999, 'score': np.float64(0.14889386106768035)},
    {'n_estimators': 500, 'learning_rate': 0.1, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 10, 'loss': 'huber', 'random_state': 420, 'totalRecords': 95700, 'totalIterations': 66.0, 'score': np.float64(0.1168549448515365)},
    {'n_estimators': 1000, 'learning_rate': 0.1, 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 10, 'loss': 'huber', 'random_state': 420, 'totalRecords': 59450, 'totalIterations': 41.0, 'score': np.float64(0.1159436203707931)},
    {'n_estimators': 1000, 'learning_rate': 0.1, 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 10, 'loss': 'huber', 'random_state': 42, 'totalRecords': 30450, 'totalIterations': 21.0, 'score': np.float64(0.11588147181989136)},
    {'n_estimators': 1000, 'learning_rate': 0.05, 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 10, 'loss': 'huber', 'random_state': 42, 'totalRecords': 43500, 'totalIterations': 29.999999999999996, 'score': np.float64(0.11323403507675124)},
    {'n_estimators': 500, 'learning_rate': 0.05, 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 10, 'loss': 'huber', 'random_state': 42, 'totalRecords': 73950, 'totalIterations': 50.99999999999999, 'score': np.float64(0.11728556765938339)},
    {'n_estimators': 1000, 'learning_rate': 0.05, 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 10, 'loss': 'huber', 'random_state': 42, 'totalRecords': 36250, 'totalIterations': 24.999999999999996, 'score': np.float64(0.11267490145829549)},
    {'n_estimators': 500, 'learning_rate': 0.01, 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 10, 'loss': 'huber', 'random_state': 420, 'totalRecords': 73950, 'totalIterations': 50.99999999999999, 'score': np.float64(0.18780295185215515)},
    {'n_estimators': 1000, 'learning_rate': 0.1, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 10, 'loss': 'huber', 'random_state': 420, 'totalRecords': 23200, 'totalIterations': 15.999999999999998, 'score': np.float64(0.1175990835370909)},
    {'n_estimators': 500, 'learning_rate': 0.1, 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 10, 'loss': 'huber', 'random_state': 42, 'totalRecords': 55100, 'totalIterations': 38.0, 'score': np.float64(0.11582098421947568)},
    {'n_estimators': 500, 'learning_rate': 0.01, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 10, 'loss': 'huber', 'random_state': 420, 'totalRecords': 37700, 'totalIterations': 25.999999999999996, 'score': np.float64(0.12421096063431909)},
    {'n_estimators': 1000, 'learning_rate': 0.05, 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 10, 'loss': 'huber', 'random_state': 42, 'totalRecords': 27550, 'totalIterations': 19.0, 'score': np.float64(0.11336113169856103)},
    {'n_estimators': 500, 'learning_rate': 0.1, 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 10, 'loss': 'huber', 'random_state': 42, 'totalRecords': 73950, 'totalIterations': 50.99999999999999, 'score': np.float64(0.11464655254853333)},
    {'n_estimators': 1000, 'learning_rate': 0.1, 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 10, 'loss': 'huber', 'random_state': 42, 'totalRecords': 59450, 'totalIterations': 41.0, 'score': np.float64(0.11548651656026529)},
    {'n_estimators': 1000, 'learning_rate': 0.1, 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 10, 'loss': 'huber', 'random_state': 42, 'totalRecords': 21750, 'totalIterations': 14.999999999999998, 'score': np.float64(0.11847559890342174)},
    {'n_estimators': 500, 'learning_rate': 0.01, 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 10, 'loss': 'huber', 'random_state': 42, 'totalRecords': 73950, 'totalIterations': 50.99999999999999, 'score': np.float64(0.18838757641014542)},
    {'n_estimators': 1000, 'learning_rate': 0.1, 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 10, 'loss': 'huber', 'random_state': 42, 'totalRecords': 37700, 'totalIterations': 25.999999999999996, 'score': np.float64(0.11552517364250936)},
    {'n_estimators': 500, 'learning_rate': 0.1, 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 10, 'loss': 'huber', 'random_state': 420, 'totalRecords': 114550, 'totalIterations': 79.0, 'score': np.float64(0.11566474089497168)},
    {'n_estimators': 500, 'learning_rate': 0.1, 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 10, 'loss': 'huber', 'random_state': 420, 'totalRecords': 147755, 'totalIterations': 101.89999999999999, 'score': np.float64(0.1205631827091519)},
    {'n_estimators': 500, 'learning_rate': 0.05, 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 10, 'loss': 'huber', 'random_state': 420, 'totalRecords': 54665, 'totalIterations': 37.699999999999996, 'score': np.float64(0.11343411240003094)},
    {'n_estimators': 500, 'learning_rate': 0.05, 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 10, 'loss': 'huber', 'random_state': 420, 'totalRecords': 147900, 'totalIterations': 101.99999999999999, 'score': np.float64(0.11519803882077038)},
    {'n_estimators': 500, 'learning_rate': 0.01, 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 10, 'loss': 'huber', 'random_state': 420, 'totalRecords': 62350, 'totalIterations': 43.0, 'score': np.float64(0.13400276918704113)},
    {'n_estimators': 1000, 'learning_rate': 0.05, 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 10, 'loss': 'huber', 'random_state': 420, 'totalRecords': 55100, 'totalIterations': 38.0, 'score': np.float64(0.11907386180659932)},
    {'n_estimators': 1000, 'learning_rate': 0.1, 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 10, 'loss': 'huber', 'random_state': 420, 'totalRecords': 36250, 'totalIterations': 24.999999999999996, 'score': np.float64(0.11455054618198734)},
    {'n_estimators': 500, 'learning_rate': 0.1, 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 10, 'loss': 'huber', 'random_state': 42, 'totalRecords': 124410, 'totalIterations': 85.8, 'score': np.float64(0.11994132162546024)},
    {'n_estimators': 500, 'learning_rate': 0.1, 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 10, 'loss': 'huber', 'random_state': 420, 'totalRecords': 81200, 'totalIterations': 55.99999999999999, 'score': np.float64(0.11813825963829064)},
    {'n_estimators': 1000, 'learning_rate': 0.05, 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 10, 'loss': 'huber', 'random_state': 420, 'totalRecords': 44950, 'totalIterations': 30.999999999999996, 'score': np.float64(0.11264997576314192)},
    {'n_estimators': 500, 'learning_rate': 0.01, 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 10, 'loss': 'huber', 'random_state': 42, 'totalRecords': 47850, 'totalIterations': 33.0, 'score': np.float64(0.12719242483636015)},
    {'n_estimators': 500, 'learning_rate': 0.1, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 10, 'loss': 'huber', 'random_state': 42, 'totalRecords': 46400, 'totalIterations': 31.999999999999996, 'score': np.float64(0.11704474215746118)},
    {'n_estimators': 1000, 'learning_rate': 0.1, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 10, 'loss': 'huber', 'random_state': 42, 'totalRecords': 24650, 'totalIterations': 17.0, 'score': np.float64(0.11770165172369784)},
    {'n_estimators': 1000, 'learning_rate': 0.1, 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 10, 'loss': 'huber', 'random_state': 420, 'totalRecords': 21750, 'totalIterations': 14.999999999999998, 'score': np.float64(0.11815286212097836)},
    {'n_estimators': 500, 'learning_rate': 0.01, 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 10, 'loss': 'huber', 'random_state': 420, 'totalRecords': 73950, 'totalIterations': 50.99999999999999, 'score': np.float64(0.14899148710554175)},
    {'n_estimators': 500, 'learning_rate': 0.1, 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 10, 'loss': 'huber', 'random_state': 420, 'totalRecords': 147900, 'totalIterations': 101.99999999999999, 'score': np.float64(0.1137423691493445)},
    {'n_estimators': 500, 'learning_rate': 0.05, 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 10, 'loss': 'huber', 'random_state': 420, 'totalRecords': 39150, 'totalIterations': 26.999999999999996, 'score': np.float64(0.1150809504751534)},
    {'n_estimators': 1000, 'learning_rate': 0.1, 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 10, 'loss': 'huber', 'random_state': 420, 'totalRecords': 46400, 'totalIterations': 31.999999999999996, 'score': np.float64(0.11290809175301217)},
    {'n_estimators': 500, 'learning_rate': 0.05, 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 10, 'loss': 'huber', 'random_state': 42, 'totalRecords': 73950, 'totalIterations': 50.99999999999999, 'score': np.float64(0.12742722395131076)},
    {'n_estimators': 500, 'learning_rate': 0.01, 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 10, 'loss': 'huber', 'random_state': 420, 'totalRecords': 31900, 'totalIterations': 22.0, 'score': np.float64(0.1226139145747624)},
    {'n_estimators': 1000, 'learning_rate': 0.05, 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 10, 'loss': 'huber', 'random_state': 420, 'totalRecords': 34800, 'totalIterations': 23.999999999999996, 'score': np.float64(0.1120272958700226)},
    {'n_estimators': 500, 'learning_rate': 0.05, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 10, 'loss': 'huber', 'random_state': 42, 'totalRecords': 44950, 'totalIterations': 30.999999999999996, 'score': np.float64(0.11410750464624464)},
    {'n_estimators': 500, 'learning_rate': 0.05, 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 10, 'loss': 'huber', 'random_state': 42, 'totalRecords': 55100, 'totalIterations': 38.0, 'score': np.float64(0.11330768980157568)},
    {'n_estimators': 500, 'learning_rate': 0.01, 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 10, 'loss': 'huber', 'random_state': 42, 'totalRecords': 31900, 'totalIterations': 22.0, 'score': np.float64(0.12234092589711647)},
    {'n_estimators': 1000, 'learning_rate': 0.05, 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 10, 'loss': 'huber', 'random_state': 42, 'totalRecords': 56550, 'totalIterations': 39.0, 'score': np.float64(0.11930532620443121)},
    {'n_estimators': 500, 'learning_rate': 0.1, 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 10, 'loss': 'huber', 'random_state': 420, 'totalRecords': 139200, 'totalIterations': 95.99999999999999, 'score': np.float64(0.11449269232837365)},
    {'n_estimators': 500, 'learning_rate': 0.01, 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 10, 'loss': 'huber', 'random_state': 42, 'totalRecords': 62350, 'totalIterations': 43.0, 'score': np.float64(0.13398666959965472)},
    {'n_estimators': 1000, 'learning_rate': 0.05, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 10, 'loss': 'huber', 'random_state': 42, 'totalRecords': 19430, 'totalIterations': 13.399999999999999, 'score': np.float64(0.11433197275390475)},
    {'n_estimators': 500, 'learning_rate': 0.05, 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 10, 'loss': 'huber', 'random_state': 420, 'totalRecords': 147900, 'totalIterations': 101.99999999999999, 'score': np.float64(0.12790801132689894)},
    {'n_estimators': 1000, 'learning_rate': 0.1, 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 10, 'loss': 'huber', 'random_state': 42, 'totalRecords': 46400, 'totalIterations': 31.999999999999996, 'score': np.float64(0.11360740281556606)},
    {'n_estimators': 500, 'learning_rate': 0.05, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 10, 'loss': 'huber', 'random_state': 420, 'totalRecords': 44950, 'totalIterations': 30.999999999999996, 'score': np.float64(0.11421757981022697)},
    {'n_estimators': 500, 'learning_rate': 0.01, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 10, 'loss': 'huber', 'random_state': 42, 'totalRecords': 37700, 'totalIterations': 25.999999999999996, 'score': np.float64(0.12400889995005795)},
    {'n_estimators': 500, 'learning_rate': 0.05, 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 10, 'loss': 'huber', 'random_state': 420, 'totalRecords': 136300, 'totalIterations': 93.99999999999999, 'score': np.float64(0.1128313071168045)},
    {'n_estimators': 500, 'learning_rate': 0.05, 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 10, 'loss': 'huber', 'random_state': 42, 'totalRecords': 66700, 'totalIterations': 46.0, 'score': np.float64(0.11368010367073408)},
    {'n_estimators': 500, 'learning_rate': 0.1, 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 10, 'loss': 'huber', 'random_state': 42, 'totalRecords': 40600, 'totalIterations': 27.999999999999996, 'score': np.float64(0.11795995591487819)},
    {'n_estimators': 500, 'learning_rate': 0.1, 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 10, 'loss': 'huber', 'random_state': 42, 'totalRecords': 68150, 'totalIterations': 46.99999999999999, 'score': np.float64(0.11543451293724717)},
    {'n_estimators': 1000, 'learning_rate': 0.1, 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 10, 'loss': 'huber', 'random_state': 420, 'totalRecords': 29000, 'totalIterations': 20.0, 'score': np.float64(0.1163063986381346)}
]

pd.DataFrame(sorted(collected, key=lambda x: x["score"]))
# Out:
#     n_estimators  learning_rate  max_depth max_features  min_samples_leaf  \
# 0           1000           0.05          3         sqrt                15
# 1           1000           0.05          2         sqrt                15
# 2           1000           0.05          3         sqrt                15
# 3            500           0.05          3         sqrt                15
# 4           1000           0.10          2         sqrt                15
# 5           1000           0.05          2         sqrt                15
# 6            500           0.05          4         sqrt                15
# 7           1000           0.05          4         sqrt                15
# 8           1000           0.05          4         sqrt                15
# 9            500           0.05          4         sqrt                15
# 10          1000           0.10          2         sqrt                15
# 11           500           0.05          3         sqrt                15
# ...

# %%
matcher = {'n_estimators': 500, 'learning_rate': 0.1, 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 10, 'loss': 'huber', 'random_state': 420}
for c in collected:
    broken = False
    for m in matcher:
        if matcher[m] != c[m]:
            broken = True
            break
    if not broken:
        print(c)
# Out:
# {'n_estimators': 500, 'learning_rate': 0.1, 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 10, 'loss': 'huber', 'random_state': 420, 'totalRecords': 147755, 'totalIterations': 101.89999999999999, 'score': np.float64(0.1205631827091519)}
